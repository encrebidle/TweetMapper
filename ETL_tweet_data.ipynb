# %%
#importing necessery libraries for future analysis of the dataset

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#!pip install tweepy
#!pip install tqdm
# Out:
# Looking in indexes: https://artifactory.micron.com/artifactory/api/pypi/zextpythonorg-pypi-rel-remote/simple
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\requests-2.25.1.dist-info\\direct_url.json'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting tweepy
#   Using cached https://artifactory.micron.com/artifactory/api/pypi/zextpythonorg-pypi-rel-remote/packages/packages/c1/fb/6114a3d464708aa5ff5ed86d926b45c0a3c8cee86ab8222480cf1e4faef5/tweepy-4.13.0-py3-none-any.whl (102 kB)
# Collecting requests-oauthlib<2,>=1.2.0
#   Using cached https://artifactory.micron.com/artifactory/api/pypi/zextpythonorg-pypi-rel-remote/packages/packages/6f/bb/5deac77a9af870143c684ab46a7934038a53eb4aa975bc0687ed6ca2c610/requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting requests<3,>=2.27.0
#   Using cached https://artifactory.micron.com/artifactory/api/pypi/zextpythonorg-pypi-rel-remote/packages/packages/d2/f4/274d1dbe96b41cf4e0efb70cbced278ffd61b5c7bb70338b62af94ccb25b/requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting oauthlib<4,>=3.2.0
#   Using cached https://artifactory.micron.com/artifactory/api/pypi/zextpythonorg-pypi-rel-remote/packages/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2020.12.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\katulya\appdata\roaming\python\python38\site-packages (from requests<3,>=2.27.0->tweepy) (2.1.1)
# Installing collected packages: requests, oauthlib, requests-oauthlib, tweepy
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
# Looking in indexes: https://artifactory.micron.com/artifactory/api/pypi/zextpythonorg-pypi-rel-remote/simple
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (4.59.0)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -quests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -quests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\katulya\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\programdata\anaconda3\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#These tweets are collected using Twitter API and Python Script
#Creating a function to get hashtag analysis
import os
import tweepy as tw
import pandas as pd
from tqdm import tqdm, notebook

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
auth = tw.OAuthHandler(api_key, api_secret)

# %%
api = tw.API(auth, wait_on_rate_limit=True)

# %%
#sword: search words like #nft -filter:retweets" fdate: from date to retreive tweets
def tweetretreive(sword,fdate):
    
    import os
    import tweepy as tw
    import pandas as pd
    from tqdm import tqdm, notebook

    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_colwidth', None)
    pd.set_option('display.width', None)
    
    auth = tw.OAuthHandler(api_key,api_secret)
    auth.set_access_token(access_key,access_secret)
    
    #auth = tw.OAuthHandler(api_key, api_secret)
    
    api = tw.API(auth, wait_on_rate_limit=True)
    
    tweets = tw.Cursor(api.search_tweets,q=sword,lang="en",since=fdate).items(10)
    
    tweets_copy = []
    
    for tweet in tqdm(tweets):
         tweets_copy.append(tweet)
    
    tweets_df = pd.DataFrame()
    for tweet in tqdm(tweets_copy):
        hashtags = []
        try:
            for hashtag in tweet.entities["hashtags"]:
                hashtags.append(hashtag["text"])
            text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
        except:
            pass
        tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                                   'user_location': tweet.user.location,\
                                                   'user_description': tweet.user.description,
                                                   'user_created': tweet.user.created_at,
                                                   'user_followers': tweet.user.followers_count,
                                                   'user_friends': tweet.user.friends_count,
                                                   'user_favourites': tweet.user.favourites_count,
                                                   'user_verified': tweet.user.verified,
                                                   'date': tweet.created_at,
                                                   'text': text, 
                                                   'hashtags': [hashtags if hashtags else None],
                                                   'source': tweet.source,
                                                   'is_retweet': tweet.retweeted}, index=[0]))
    
    #Read past fetched data if exists
    #tweets_old_df = pd.read_csv("covid19_tweets.csv")
    #Merge both old and new data
    #tweets_all_df = pd.concat([tweets_old_df, tweets_df], axis=0)
    #Removing duplicates if exists
    #tweets_all_df.drop_duplicates(subset = ["user_name", "date", "text"], inplace=True)
    #exporting data to update csv
    #tweets_all_df.to_csv("covid19_tweets.csv", index=False)
    
    return tweets_df

# %%
finaldf = tweetretreive("# -filter:retweets","2016-03-01")
# Out:
# 0it [00:00, ?it/s]Unexpected parameter: since
# 1it [00:01,  1.85s/it]Unexpected parameter: since
# 5it [00:03,  1.59it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:06<00:00,  1.35s/it]

# %%
finaldf
# Out:
#      user_name user_location  \
# 0        Kiran
# 0     HANS RAJ
# 0  lifeandmore         India
# 0  Muktar khan          भारत
# 0   Elon Musik
#
#                                                                                                  user_description  \
# 0
# 0                                                                                                          HITMAN
# 0  Lifestyle & Entertainment Features website. Email news/ feature story leads/ tips to lifeandmoreplus@gmail.com
# 0                                                                                                             Srk
# 0
#
#                user_created  user_followers  user_friends  user_favourites  \
# 0 2022-12-14 03:28:58+00:00               0             7                1
# 0 2023-03-12 18:42:14+00:00               3            62                3
# 0 2018-03-19 12:24:43+00:00              59           186             1471
# 0 2019-01-15 00:52:53+00:00              45           621             6269
# 0 2011-01-13 19:17:07+00:00              52           223             8293
#
#    user_verified                      date  \
# 0          False 2023-04-14 15:28:30+00:00
# 0          False 2023-04-11 05:44:35+00:00
# 0          False 2023-04-10 16:48:36+00:00
# 0          False 2023-04-10 10:29:20+00:00
# 0          False 2023-04-09 21:43:08+00:00
#
#                                                                                                                                                                                                                                                                                     text  \
# 0                                                                                        @MediaCellSP @yadavakhilesh So you are supporting him because he was #Yadav\n#Casteist #Shameful #DivideAndRule\nHere 👇SP Leader  shaking hand with mafiya don’s #Kutta https://t.co/OxewtgY3hf
# 0                                                                                  @LucknowIPL If You Have #Kutta Kohli in your team then it’s impossible to PLAY BOLD.   First of all release this dog 🐕 out of the world. \n\n@RCBTweets @DaleSteyn62 @imVkohli @GautamGambhir @iamsrk
# 0  Six humorously named destinations around the world https://t.co/lvDySzEFei via @httpstwittercomlifeandmoreplus #lifeandmore #lifeandmoreplus #lifemoreplus #travel #travellers #humourous #humourousnames #vacation #kutta #krk #obama #drama #sauce #booking #bookingcom @bookingcom
# 0                                         @HuzaifaKhan021 Najam Sethi: \n"Babar Azam will remain captain of Pakistan Cricket Team as far as he kept performing individually &amp; as captain \nBut Me :\nHow long Najam Sethi will be chairman PCB?\nalso me : Till change in Gov #kutta
# 0                                                                                                                                                                          @BBhuttoZardari \n\nYou are freaking psychopath \n\nKhanzeer ki aulaad \n\n#psychopath \n#kutta \n#PPPDigital
#
#                                      hashtags               source  is_retweet
# 0  [Yadav, Casteist, Shameful, DivideAndRule]     Twitter for iPad       False
# 0                                     [Kutta]   Twitter for iPhone       False
# 0                                        None      Twitter Web App       False
# 0                                        None  Twitter for Android       False
# 0             [psychopath, kutta, PPPDigital]      Twitter Web App       False

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import folium
from folium.plugins import HeatMapWithTime, TimestampedGeoJson

tweets = pd.read_csv('modi_tweets.csv')

# %%
tweets.head()
# Out:
#               user_name       user_location  \
# 0  🐣❤️🦂♏🎼 Uηđеrjusτιсеđ                 NaN
# 1                 Ranga             Chennai
# 2              Riaz Haq  Silicon Valley, CA
# 3               Bharath      Chennai, India
# 4        Ayarkar Raghu.       Mumbai, India
#
#                                                                                                                                                   user_description  \
# 0  Love is sacred & its eligibility is only attained by spirituality. Love without respect, honour, dignity, self-control & patience is lust. (views are personal)
# 1                                                                                                                         Lean manufacturing, Financial analyst 🇮🇳
# 2           Riaz Haq writes this blog to express his opinions and make comments on wide ranging topics.The subjects include events in Pakistan and Silicon Valley.
# 3                                                                                                                                             Nationalist | Modist
# 4                                                                                                                         AI ML 3D printing #technology enthusiast
#
#                 user_created  user_followers  user_friends  user_favourites  \
# 0  2020-06-26 13:06:07+00:00             132           103            15813
# 1  2009-08-17 06:10:22+00:00              72           135              625
# 2  2009-01-19 04:00:06+00:00            4162           477            28796
# 3  2022-08-08 11:00:42+00:00               8           354                8
# 4  2018-03-11 02:46:40+00:00              14           207               99
#
#    user_verified                       date  \
# 0          False  2023-04-16 17:12:54+00:00
# 1          False  2023-04-16 17:12:44+00:00
# 2          False  2023-04-16 17:11:45+00:00
# 3          False  2023-04-16 16:58:39+00:00
# 4          False  2023-04-16 16:58:18+00:00
#
#                                                                                                                                                                                                                                                                                                                                              text  \
# 0  For #Indian followers of @FriedrichPieter.\nAcc. to US Commerce @SecRaimondo, #Modi, the Butcher of Gujarat who was banned from America for 10 yrs, is: “Unbelievable. Visionary. Visionary! &amp; his level of commitment to the ppl of India is just indescribable.\nhttps://t.co/rU9DPnUXyE https://t.co/UUrOSCtJnq https://t.co/lgpnN2CriP
# 1                                                                                                                                                                                                                                                                                     @rose_k01 No doubt the secular people are jealous of #Modi!
# 2                                                                          Ex-IIOJK governor’s revelations on #Pulwama (#Kashmir) attack vindicate #Pakistan.  #Indian PM #Modi wanted to use the attack to blame Pakis­tan for the benefit of his government and the #BJP to win the 2019 elections in #India. #Balakot  https://t.co/caKXQFJ0tq
# 3                                                                                                                                                                                                                                         Modiji's Gujarat and French Fries\n@narendramodi @PMOIndia #India #Modi #Modist https://t.co/g4WodQcm2z
# 4                                                                                                                                               @Mehboobp1 @RahulGandhi We will kick out congress. We don't want karnataka to become kerla or wb. Nandini no one can kick out..it is karnataka pride. #Modi #congresshatesobc #CongressMuktBharat
#
#                                                hashtags               source  \
# 0                                    ['Indian', 'Modi']  Twitter for Android
# 1                                              ['Modi']   Twitter for iPhone
# 2  ['Pulwama', 'Kashmir', 'Pakistan', 'Indian', 'Modi']      Twitter Web App
# 3                           ['India', 'Modi', 'Modist']  Twitter for Android
# 4                                                   NaN  Twitter for Android
#
#    is_retweet
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
cities = pd.read_csv('datasets/worldcities.csv')

# %%
cities.head()
# Out:
#           city   city_ascii      lat       lng        country iso2 iso3  \
# 0        Tokyo        Tokyo  35.6850  139.7514          Japan   JP  JPN
# 1     New York     New York  40.6943  -73.9249  United States   US  USA
# 2  Mexico City  Mexico City  19.4424  -99.1310         Mexico   MX  MEX
# 3       Mumbai       Mumbai  19.0170   72.8570          India   IN  IND
# 4    São Paulo    Sao Paulo -23.5587  -46.6250         Brazil   BR  BRA
#
#          admin_name  capital  population          id
# 0             Tōkyō  primary  35676000.0  1392685764
# 1          New York      NaN  19354922.0  1840034016
# 2  Ciudad de México  primary  19028000.0  1484247881
# 3       Mahārāshtra    admin  18978000.0  1356226629
# 4         São Paulo    admin  18845000.0  1076532519
